# %% [markdown]
# # Prophet Model
# Weekly challenge: Week 6
# Date: 8/29/2022

# %%
# pip install pystan
# pip install fbprophet

# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the dataset
data = pd.read_csv(r'C:\Users\unpat\_Projects\Challenge_AprojectAweek\Week_06\Customers_in_a_Shop.csv', header = None)

# Assigning names to the columns
data.columns = ['Date','Customers']

# Converting Date column from object to datetime
data['Date'] = pd.to_datetime(data['Date'], format = "%Y-%m")

# Setting index to Date
data = data.set_index('Date')

data.shape
# Out:
# (144, 1)

# %%
data.head()
# Out:
#             Customers
# Date
# 1949-01-01      114.0
# 1949-02-01      120.0
# 1949-03-01      134.0
# 1949-04-01       67.0
# 1949-05-01      123.0

# %%
plt.rcParams['figure.figsize'] = (15, 5)
plt.plot(data, color = 'black')
plt.title("Number of Customers Visiting an Ice Cream Shope Since 1949")
plt.show()

# %%
# Splitting data into train and test sets
length_train = 115
train = data.iloc[:length_train, :]
test = data.iloc[length_train:, :]

# %% [markdown]
# ## Prophet model building

# %%
from fbprophet import Prophet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19760/1130067940.py in <module>
# ----> 1 from fbprophet import Prophet
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
pwd
# Out:
# 'C:\\Users\\unpat\\_Projects\\Challenge_AProjectAWeek\\Week_07'

# %%
# !conda install -c conda-forge fbprophet -y
# Out:
# ^C
